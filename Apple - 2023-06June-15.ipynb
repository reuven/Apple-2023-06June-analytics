# %% [markdown]
# # Agenda
#
# 1. String in a series
# 2. Data frame
#     - Creating
#     - Retrieving from a data frame
#     - Methods on a data frame

# %%
import numpy as np
import pandas as pd
from pandas import Series, DataFrame

# %%
s = Series([10, 20, 30])
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int64

# %%
s = Series([10, 20, 30], dtype=np.int8)
s
# Out:
# 0    10
# 1    20
# 2    30
# dtype: int8

# %%
s.dtype
# Out:
# dtype('int8')

# %%
s.dtype = np.float16
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# File /usr/local/lib/python3.11/site-packages/pandas/core/generic.py:6020, in NDFrame.__setattr__(self, name, value)
#    6019     else:
# -> 6020         object.__setattr__(self, name, value)
#    6021 except (AttributeError, TypeError):
#
# AttributeError: property 'dtype' of 'Series' object has no setter
#
# During handling of the above exception, another exception occurred:
#
# AttributeError                            Traceback (most recent call last)
# Cell In [6], line 1
# ----> 1 s.dtype = np.float16
#
# File /usr/local/lib/python3.11/site-packages/pandas/core/generic.py:6030, in NDFrame.__setattr__(self, name, value)
#    6022 if isinstance(self, ABCDataFrame) and (is_list_like(value)):
#    6023     warnings.warn(
#    6024         "Pandas doesn't allow columns to be "
#    6025         "created via a new attribute name - see "
#    (...)
#    6028         stacklevel=find_stack_level(),
#    6029     )
# -> 6030 object.__setattr__(self, name, value)
#
# AttributeError: property 'dtype' of 'Series' object has no setter

# %%
s.astype(np.float16)
# Out:
# 0    10.0
# 1    20.0
# 2    30.0
# dtype: float16

# %%
a = np.array('hello out there'.split())
a
# Out:
# array(['hello', 'out', 'there'], dtype='<U5')
