# %%
def mysum(*numbers):
    total = 0
    for one_number in numbers:
        total += one_number
    return total

# %%
mysum(10, 20, 30)
# Out:
# 60

# %%
mysum(100, 200, 300)
# Out:
# 600

# %%
mysum([10, 20, 30])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In [5], line 1
# ----> 1 mysum([10, 20, 30])
#
# Cell In [1], line 4, in mysum(*numbers)
#       2 total = 0
#       3 for one_number in numbers:
# ----> 4     total += one_number
#       5 return total
#
# TypeError: unsupported operand type(s) for +=: 'int' and 'list'
